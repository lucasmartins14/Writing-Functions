# %% [markdown]
# # Docstring formats

# %% [markdown]
# ## Estilos de docstring mais populares:
# ### - Estilo Google
# ### - Estilo Numpydoc

# %%
# Google

def function(arg_1, arg_2=42):
    """
    Descrição do que a função faz (de modo imperativa)

    Args:
    Listar cada nome de argumento seguido por seu tipo esperado entre parênteses, e qual seu papel na função

    Return:
    Listar o tipo ou tipos esperados do que retornado

    Raises:
    Se a função gerar erros intencionamente

    Notas:
    Se for necessário
    """

# %%
# Numpydoc + comum na comunidade

def function(arg_1, arg_2=42):
    """
    Descrição do que a função faz (de modo imperativa)

    Parametros
    ----------

    Returns
    ---------
    
    """

# %%
# Para acessar as docstrings com __doc__

def function(arg_1, arg_2=42):
    """
    Descrição do que a função faz (de modo imperativa)

    Parametros
    ----------

    Returns
    ---------
    
    """
print(function.__doc__)
# Out:
#     Descrição do que a função faz (de modo imperativa)
#
#     Parametros
#     ----------
#
#     Returns
#     ---------

# %%
# Para acessar as docstrings com inspect

import inspect


def function(arg_1, arg_2=42):
    """
    Descrição do que a função faz (de modo imperativa)

    Parametros
    ----------

    Returns
    ---------
    
    """
print(inspect.getdoc(function))
# Out:
# Descrição do que a função faz (de modo imperativa)
#
# Parametros
# ----------
#
# Returns
# ---------

# %% [markdown]
# #### Exemplo Google Style

# %%
def count_letter(content, letter):
  """Count the number of times `letter` appears in `content`.

  Args:
    content (str): The string to search.
    letter (str): The letter to search for.

  Returns:
    int

  # Add a section detailing what errors might be raised
  Raises:
    ValueError: If `letter` is not a one-character string.
  """
  if (not isinstance(letter, str)) or len(letter) != 1:
    raise ValueError('`letter` must be a single character string.')
  return len([char for char in content if char == letter])
